# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'c:\Users\TEMP.JS-L1-31\Desktop\ict\venv\Scripts\python.exe -m pip install --upgrade pip' command.
#   Downloading pandas-2.1.4-cp39-cp39-win_amd64.whl (10.8 MB)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Collecting numpy<2,>=1.22.4
#   Downloading numpy-1.26.3-cp39-cp39-win_amd64.whl (15.8 MB)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\temp.js-l1-31\desktop\ict\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\temp.js-l1-31\desktop\ict\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
# Successfully installed numpy-1.26.3 pandas-2.1.4 pytz-2023.3.post1 tzdata-2023.4

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 23.3.2 is available.
# You should consider upgrading via the 'c:\Users\TEMP.JS-L1-31\Desktop\ict\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
df=pd.read_excel("Olympic Athletes.xlsx")

# %%
df
# Out:
#                    Athlete   Age        Country  Year Closing Ceremony Date  \
# 0           Michael Phelps  23.0  United States  2008            2008-08-24
# 1           Michael Phelps  19.0  United States  2004            2004-08-29
# 2           Michael Phelps  27.0  United States  2012            2012-08-12
# 3         Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4            Aleksey Nemov  24.0         Russia  2000            2000-10-01
# ...                    ...   ...            ...   ...                   ...
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
#            Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0       Swimming            8              0              0             8
# 1       Swimming            6              0              2             8
# 2       Swimming            4              2              0             6
# 3       Swimming            1              2              3             6
# 4     Gymnastics            2              1              3             6
# ...          ...          ...            ...            ...           ...
# 8613     Archery            0              1              0             1
# 8614     Archery            0              1              0             1
# 8615     Archery            0              0              1             1
# 8616     Archery            0              0              1             1
# 8617     Archery            0              0              1             1
#
# [8618 rows x 10 columns]

# %%
df.shape
# Out:
# (8618, 10)

# %%
df.head
# Out:
# <bound method NDFrame.head of                    Athlete   Age        Country  Year Closing Ceremony Date  \
# 0           Michael Phelps  23.0  United States  2008            2008-08-24
# 1           Michael Phelps  19.0  United States  2004            2004-08-29
# 2           Michael Phelps  27.0  United States  2012            2012-08-12
# 3         Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4            Aleksey Nemov  24.0         Russia  2000            2000-10-01
# ...                    ...   ...            ...   ...                   ...
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
#            Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0       Swimming            8              0              0             8
# 1       Swimming            6              0              2             8
# 2       Swimming            4              2              0             6
# 3       Swimming            1              2              3             6
# 4     Gymnastics            2              1              3             6
# ...          ...          ...            ...            ...           ...
# 8613     Archery            0              1              0             1
# 8614     Archery            0              1              0             1
# 8615     Archery            0              0              1             1
# 8616     Archery            0              0              1             1
# 8617     Archery            0              0              1             1
#
# [8618 rows x 10 columns]>

# %%
df.head()
# Out:
#             Athlete   Age        Country  Year Closing Ceremony Date  \
# 0    Michael Phelps  23.0  United States  2008            2008-08-24
# 1    Michael Phelps  19.0  United States  2004            2004-08-29
# 2    Michael Phelps  27.0  United States  2012            2012-08-12
# 3  Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4     Aleksey Nemov  24.0         Russia  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 0    Swimming            8              0              0             8
# 1    Swimming            6              0              2             8
# 2    Swimming            4              2              0             6
# 3    Swimming            1              2              3             6
# 4  Gymnastics            2              1              3             6

# %%
df.head(15)
# Out:
#              Athlete   Age        Country  Year Closing Ceremony Date  \
# 0     Michael Phelps  23.0  United States  2008            2008-08-24
# 1     Michael Phelps  19.0  United States  2004            2004-08-29
# 2     Michael Phelps  27.0  United States  2012            2012-08-12
# 3   Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4      Aleksey Nemov  24.0         Russia  2000            2000-10-01
# 5      Alicia Coutts  24.0      Australia  2012            2012-08-12
# 6     Missy Franklin  17.0  United States  2012            2012-08-12
# 7        Ryan Lochte  27.0  United States  2012            2012-08-12
# 8    Allison Schmitt  22.0  United States  2012            2012-08-12
# 9   Natalie Coughlin  21.0  United States  2004            2004-08-29
# 10        Ian Thorpe  17.0      Australia  2000            2000-10-01
# 11       Dara Torres  33.0  United States  2000            2000-10-01
# 12     Cindy Klassen  26.0         Canada  2006            2006-02-26
# 13     Nastia Liukin  18.0  United States  2008            2008-08-24
# 14     Marit Bjørgen  29.0         Norway  2010            2010-02-28
#
#                    Sport  Gold Medals  Silver Medals  Bronze Medals  \
# 0               Swimming            8              0              0
# 1               Swimming            6              0              2
# 2               Swimming            4              2              0
# 3               Swimming            1              2              3
# 4             Gymnastics            2              1              3
# 5               Swimming            1              3              1
# 6               Swimming            4              0              1
# 7               Swimming            2              2              1
# 8               Swimming            3              1              1
# 9               Swimming            2              2              1
# 10              Swimming            3              2              0
# 11              Swimming            2              0              3
# 12         Speed Skating            1              2              2
# 13            Gymnastics            1              3              1
# 14  Cross Country Skiing            3              1              1
#
#     Total Medals
# 0              8
# 1              8
# 2              6
# 3              6
# 4              6
# 5              5
# 6              5
# 7              5
# 8              5
# 9              5
# 10             5
# 11             5
# 12             5
# 13             5
# 14             5

# %%
df.tail()
# Out:
#                    Athlete   Age        Country  Year Closing Ceremony Date  \
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 8613  Archery            0              1              0             1
# 8614  Archery            0              1              0             1
# 8615  Archery            0              0              1             1
# 8616  Archery            0              0              1             1
# 8617  Archery            0              0              1             1

# %%
df.tail(10)
# Out:
#                    Athlete   Age        Country  Year Closing Ceremony Date  \
# 8608         Butch Johnson  45.0  United States  2000            2000-10-01
# 8609        Kim Cheong-Tae  20.0    South Korea  2000            2000-10-01
# 8610       Barbara Mensing  39.0        Germany  2000            2000-10-01
# 8611             O Gyo-Mun  28.0    South Korea  2000            2000-10-01
# 8612        Cornelia Pfohl  29.0        Germany  2000            2000-10-01
# 8613      Olena Sadovnycha  32.0        Ukraine  2000            2000-10-01
# 8614      Kateryna Serdiuk  17.0        Ukraine  2000            2000-10-01
# 8615      Wietse van Alten  21.0    Netherlands  2000            2000-10-01
# 8616  Sandra Wagner-Sachse  31.0        Germany  2000            2000-10-01
# 8617             Rod White  23.0  United States  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 8608  Archery            0              0              1             1
# 8609  Archery            1              0              0             1
# 8610  Archery            0              0              1             1
# 8611  Archery            1              0              0             1
# 8612  Archery            0              0              1             1
# 8613  Archery            0              1              0             1
# 8614  Archery            0              1              0             1
# 8615  Archery            0              0              1             1
# 8616  Archery            0              0              1             1
# 8617  Archery            0              0              1             1

# %%
df.sample()
# Out:
#              Athlete   Age Country  Year Closing Ceremony Date     Sport  \
# 6837  Henrik Nilsson  28.0  Sweden  2004            2004-08-29  Canoeing
#
#       Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 6837            1              0              0             1

# %%
df.sample(5)
# Out:
#                     Athlete   Age  Country  Year Closing Ceremony Date  \
# 5105        Olena Radchenko  31.0  Ukraine  2004            2004-08-29
# 860        Atryom Kyuregyan  27.0   Greece  2004            2004-08-29
# 6840       Markus Oscarsson  27.0   Sweden  2004            2004-08-29
# 122   Yelena Zamolodchikova  17.0   Russia  2000            2000-10-01
# 8067      Vadim Devyatovsky  31.0  Belarus  2008            2008-08-24
#
#            Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals
# 5105    Handball            0              0              1             1
# 860    Wrestling            0              0              1             1
# 6840    Canoeing            1              0              0             1
# 122   Gymnastics            2              1              0             3
# 8067   Athletics            0              1              0             1

# %%
df.size
# Out:
# 86180

# %%
df.shape
# Out:
# (8618, 10)

# %%
df.columns
# Out:
# Index(['Athlete', 'Age', 'Country', 'Year', 'Closing Ceremony Date', 'Sport',
#        'Gold Medals', 'Silver Medals', 'Bronze Medals', 'Total Medals'],
#       dtype='object')

# %%
df['Age']
# Out:
# 0       23.0
# 1       19.0
# 2       27.0
# 3       25.0
# 4       24.0
#         ...
# 8613    32.0
# 8614    17.0
# 8615    21.0
# 8616    31.0
# 8617    23.0
# Name: Age, Length: 8618, dtype: float64

# %%
df['Country']
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4              Russia
#             ...
# 8613          Ukraine
# 8614          Ukraine
# 8615      Netherlands
# 8616          Germany
# 8617    United States
# Name: Country, Length: 8618, dtype: object

# %%
df['Gold Medals']
# Out:
# 0       8
# 1       6
# 2       4
# 3       1
# 4       2
#        ..
# 8613    0
# 8614    0
# 8615    0
# 8616    0
# 8617    0
# Name: Gold Medals, Length: 8618, dtype: int64

# %%
df[['Athlete', 'Age', 'Country']]
# Out:
#                    Athlete   Age        Country
# 0           Michael Phelps  23.0  United States
# 1           Michael Phelps  19.0  United States
# 2           Michael Phelps  27.0  United States
# 3         Natalie Coughlin  25.0  United States
# 4            Aleksey Nemov  24.0         Russia
# ...                    ...   ...            ...
# 8613      Olena Sadovnycha  32.0        Ukraine
# 8614      Kateryna Serdiuk  17.0        Ukraine
# 8615      Wietse van Alten  21.0    Netherlands
# 8616  Sandra Wagner-Sachse  31.0        Germany
# 8617             Rod White  23.0  United States
#
# [8618 rows x 3 columns]

# %%
df[['Silver Medals', 'Bronze Medals', 'Total Medals']]
# Out:
#       Silver Medals  Bronze Medals  Total Medals
# 0                 0              0             8
# 1                 0              2             8
# 2                 2              0             6
# 3                 2              3             6
# 4                 1              3             6
# ...             ...            ...           ...
# 8613              1              0             1
# 8614              1              0             1
# 8615              0              1             1
# 8616              0              1             1
# 8617              0              1             1
#
# [8618 rows x 3 columns]

# %%
df[['Silver Medals', 'Bronze Medals', 'Total Medals','Athlete', 'Age']]
# Out:
#       Silver Medals  Bronze Medals  Total Medals               Athlete   Age
# 0                 0              0             8        Michael Phelps  23.0
# 1                 0              2             8        Michael Phelps  19.0
# 2                 2              0             6        Michael Phelps  27.0
# 3                 2              3             6      Natalie Coughlin  25.0
# 4                 1              3             6         Aleksey Nemov  24.0
# ...             ...            ...           ...                   ...   ...
# 8613              1              0             1      Olena Sadovnycha  32.0
# 8614              1              0             1      Kateryna Serdiuk  17.0
# 8615              0              1             1      Wietse van Alten  21.0
# 8616              0              1             1  Sandra Wagner-Sachse  31.0
# 8617              0              1             1             Rod White  23.0
#
# [8618 rows x 5 columns]

# %%
import numpy as np

# %%
df['first_five_country']=df['Country'].str[:5]
print(df.head())
# Out:
#             Athlete   Age        Country  Year Closing Ceremony Date  \
# 0    Michael Phelps  23.0  United States  2008            2008-08-24
# 1    Michael Phelps  19.0  United States  2004            2004-08-29
# 2    Michael Phelps  27.0  United States  2012            2012-08-12
# 3  Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4     Aleksey Nemov  24.0         Russia  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals  \
# 0    Swimming            8              0              0             8
# 1    Swimming            6              0              2             8
# 2    Swimming            4              2              0             6
# 3    Swimming            1              2              3             6
# 4  Gymnastics            2              1              3             6
#
#   first_five_country
# 0              Unite
# 1              Unite
# 2              Unite
# 3              Unite
# 4              Russi

# %%
df['first_five_letter_1']=df['Country'].str.extract(r'(^w{5})')

# %%
df.head()
# Out:
#             Athlete   Age        Country  Year Closing Ceremony Date  \
# 0    Michael Phelps  23.0  United States  2008            2008-08-24
# 1    Michael Phelps  19.0  United States  2004            2004-08-29
# 2    Michael Phelps  27.0  United States  2012            2012-08-12
# 3  Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4     Aleksey Nemov  24.0         Russia  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals  \
# 0    Swimming            8              0              0             8
# 1    Swimming            6              0              2             8
# 2    Swimming            4              2              0             6
# 3    Swimming            1              2              3             6
# 4  Gymnastics            2              1              3             6
#
#   first_five_country first_five_letter_1
# 0              Unite                 NaN
# 1              Unite                 NaN
# 2              Unite                 NaN
# 3              Unite                 NaN
# 4              Russi                 NaN

# %%
print(df.head())
# Out:
#             Athlete   Age        Country  Year Closing Ceremony Date  \
# 0    Michael Phelps  23.0  United States  2008            2008-08-24
# 1    Michael Phelps  19.0  United States  2004            2004-08-29
# 2    Michael Phelps  27.0  United States  2012            2012-08-12
# 3  Natalie Coughlin  25.0  United States  2008            2008-08-24
# 4     Aleksey Nemov  24.0         Russia  2000            2000-10-01
#
#         Sport  Gold Medals  Silver Medals  Bronze Medals  Total Medals  \
# 0    Swimming            8              0              0             8
# 1    Swimming            6              0              2             8
# 2    Swimming            4              2              0             6
# 3    Swimming            1              2              3             6
# 4  Gymnastics            2              1              3             6
#
#   first_five_country first_five_letter_1
# 0              Unite                 NaN
# 1              Unite                 NaN
# 2              Unite                 NaN
# 3              Unite                 NaN
# 4              Russi                 NaN

# %%
import pandas as pd

S = pd.Series(['Norway', 'Colombia', 'Netherlands', 'Japan', 'Puerto Rico', 'Russia', 'New York'])

# Select elements in the Series where the pattern (^N.*) matches exactly once
result_series = S[S.str.count(r'(^N.*)') == 1]

# Display the result Series
print(result_series)

# Use sum() to find the total elements matching the pattern
total_matching_elements = S.str.count(r'(^N.*)').sum()
print("Total matching elements:", total_matching_elements)
# Out:
# 0         Norway
# 2    Netherlands
# 6       New York
# dtype: object
# Total matching elements: 3

# %%
import pandas as pd

S = pd.Series(['Finland', 'Colombia', 'Florida', 'Japan','Peru', 'Puerto Rico', 'Russia', 'France'])

# Select elements in the Series where the values start with 'P'
result_series = S[S.str.match(r'^P.*')]

# Display the result Series
print(result_series)
# Out:
# 4           Peru
# 5    Puerto Rico
# dtype: object

# %%
import pandas as pd

S = pd.Series(['Finland', 'Colombia', 'Florida', 'Japan', 'Puerto Rico', 'Russia', 'France'])

# Select elements in the Series where the values start with 'P'
result_series = S[S.str.endswith(r'^*.a')]

# Display the result Series
print(result_series)
# Out:
# Series([], dtype: object)

# %%
df[df['Athlete'].str.match('^P.*')==True]
# Out:
#                         Athlete   Age        Country  Year  \
# 20                Petria Thomas  28.0      Australia  2004
# 27    Pieter van den Hoogenband  22.0    Netherlands  2000
# 33           Petter Northug Jr.  24.0         Norway  2010
# 58                 Pang Jiaying  23.0          China  2008
# 79    Pieter van den Hoogenband  26.0    Netherlands  2004
# ...                         ...   ...            ...   ...
# 8217                  Pat Dwyer  26.0      Australia  2004
# 8255        Paul Kipsiele Koech  22.0          Kenya  2004
# 8465         Passion Richardson  25.0  United States  2000
# 8487                Paul Tergat  31.0          Kenya  2000
# 8592             Park Gyeong-Mo  28.0    South Korea  2004
#
#      Closing Ceremony Date                 Sport  Gold Medals  Silver Medals  \
# 20              2004-08-29              Swimming            3              1
# 27              2000-10-01              Swimming            2              0
# 33              2010-02-28  Cross Country Skiing            2              1
# 58              2008-08-24              Swimming            0              1
# 79              2004-08-29              Swimming            1              2
# ...                    ...                   ...          ...            ...
# 8217            2004-08-29             Athletics            0              1
# 8255            2004-08-29             Athletics            0              0
# 8465            2000-10-01             Athletics            0              0
# 8487            2000-10-01             Athletics            0              1
# 8592            2004-08-29               Archery            1              0
#
#       Bronze Medals  Total Medals first_five_country first_five_letter_1
# 20                0             4              Austr                 NaN
# 27                2             4              Nethe                 NaN
# 33                1             4              Norwa                 NaN
# 58                2             3              China                 NaN
# 79                0             3              Nethe                 NaN
# ...             ...           ...                ...                 ...
# 8217              0             1              Austr                 NaN
# 8255              1             1              Kenya                 NaN
# 8465              1             1              Unite                 NaN
# 8487              0             1              Kenya                 NaN
# 8592              0             1              South                 NaN
#
# [259 rows x 12 columns]

# %%
import pandas as pd

S = pd.Series(['Finland-1', 'Colombia-2', 'Florida-3', 'Japan-4', 'Puerto Rico-5', 'Russia-6', 'France-7'])

# Replace the pattern '(-\d)' with an empty string
S.replace('(-\d)', '', regex=True, inplace=True)

# Display the modified Series
print(S)
# Out:
# 0        Finland
# 1       Colombia
# 2        Florida
# 3          Japan
# 4    Puerto Rico
# 5         Russia
# 6         France
# dtype: object

# %% [markdown]
# Contains

# %%
result=S.str.contains('^F.*')
print(result)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
df[df['Country'].str.contains('^I.*')==True]
# Out:
#                     Athlete   Age Country  Year Closing Ceremony Date  \
# 83    Massimiliano Rosolino  22.0   Italy  2000            2000-10-01
# 97            Enrico Fabris  24.0   Italy  2006            2006-02-26
# 129       Stefania Belmondo  33.0   Italy  2002            2002-02-24
# 264     Domenico Fioravanti  23.0   Italy  2000            2000-10-01
# 337       Niccolò Campriani  24.0   Italy  2012            2012-08-12
# ...                     ...   ...     ...   ...                   ...
# 8578          Mauro Nespoli  20.0   Italy  2008            2008-08-24
# 8585         Marco Galiazzo  21.0   Italy  2004            2004-08-29
# 8602         Matteo Bisiani  24.0   Italy  2000            2000-10-01
# 8604          Ilario Di Buò  43.0   Italy  2000            2000-10-01
# 8606      Michele Frangilli  24.0   Italy  2000            2000-10-01
#
#                      Sport  Gold Medals  Silver Medals  Bronze Medals  \
# 83                Swimming            1              1              1
# 97           Speed Skating            2              0              1
# 129   Cross Country Skiing            1              1              1
# 264               Swimming            2              0              0
# 337               Shooting            1              1              0
# ...                    ...          ...            ...            ...
# 8578               Archery            0              1              0
# 8585               Archery            1              0              0
# 8602               Archery            0              1              0
# 8604               Archery            0              1              0
# 8606               Archery            0              1              0
#
#       Total Medals first_five_country first_five_letter_1
# 83               3              Italy                 NaN
# 97               3              Italy                 NaN
# 129              3              Italy                 NaN
# 264              2              Italy                 NaN
# 337              2              Italy                 NaN
# ...            ...                ...                 ...
# 8578             1              Italy                 NaN
# 8585             1              Italy                 NaN
# 8602             1              Italy                 NaN
# 8604             1              Italy                 NaN
# 8606             1              Italy                 NaN
#
# [392 rows x 12 columns]
